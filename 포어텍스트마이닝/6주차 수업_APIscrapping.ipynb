# %% [markdown]
# ### API 활용 Scrapping
# #### 0408 수업
# - API Scrapping
# - json 타입 학습
# - 이를 활용한 자료 타입 뽑아오기

# %% [markdown]
# - 웹스크랩핑 허용 범위 확인하고 스크랩핑할 것 _ robot.txt
# - permission 받고 진행할 것 => API 이용
# - 오늘까지하면 크롤링, 웹스크랩핑은 다 끝남. 외에는 gutenberg 같은 직접 다운
#     - gutenberg내에 mac_morpho: MAC-MORPHO: Brazilian Portuguese news text with part-of-speech tags 있음
#     - nltk 공식 문서 https://www.nltk.org/howto/portuguese_en.html

# %%
import nltk

# %%
nltk.download('mac_morpho')
from nltk.corpus import mac_morpho
# Out:
# [nltk_data] Downloading package mac_morpho to
# [nltk_data]     C:\Users\bestl\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\mac_morpho.zip.

# %%
sentences = mac_morpho.sents()
for sentence in sentences[:5]:
    print(sentence)
# Out:
# ['Jersei', 'atinge', 'média', 'de', 'Cr$', '1,4', 'milhão', 'em', 'a', 'venda', 'de', 'a', 'Pinhal', 'em', 'São', 'Paulo']
# ['Programe', 'sua', 'viagem', 'a', 'a', 'Exposição', 'Nacional', 'do', 'Zebu', ',', 'que', 'começa', 'dia', '25']
# ['Safra', 'recorde', 'e', 'disponibilidade', 'de', 'crédito', 'ativam', 'vendas', 'de', 'máquinas', 'agrícolas']
# ['A', 'degradação', 'de', 'as', 'terras', 'por', 'o', 'mau', 'uso', 'de', 'os', 'solos', 'avança', 'em', 'o']
# ['A', 'desertificação', 'tornou', 'crítica', 'a', 'produtividade', 'de', '52', 'mil', 'km²', 'em', 'a', 'região']

# %% [markdown]
# #### API 인터페이스
# - 컴퓨터와 컴퓨터를 연결하는 인터페이스. 프로그램 간 데이터 get-post어떤 방식으로 할지에 대한 규칙
# - 데이터 수집 시 가장 안정적인 방식
# - 정보 요청 코드: GET 정도 알면됨(Delete, patch, post, put)
# - 응답 코드: 200ok, 500 server error, 400 inavailable(userfault), 300 redirection error

# %% [markdown]
# ### JSON
# - Javascript object Notation
# - 데이터 교환 양식 format
# - csv는 정형이지만 json은 반정형데이터임 _ 뭔가 규칙이 있지만 귀찮은..!

# %% [markdown]
# ### API 다룰 시 주피터에 하면 매번 다시 돌려줘야함
# - colab은 맨날...마운트...!

# %% [markdown]
# ### API 클라이언트 실행

# %% [markdown]
# - $ disply = 20 같은건 url code로 불리고 언어 통일

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "hSEKHkgAg9FvizNuqxMG"
client_secret = "7AlTvkl1LN"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2017-01-01\",\"endDate\":\"2017-04-30\",\"timeUnit\":\"month\",\"keywordGroups\":[{\"groupName\":\"한글\",\"keywords\":[\"한글\",\"korean\"]},{\"groupName\":\"영어\",\"keywords\":[\"영어\",\"english\"]}],\"device\":\"pc\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2017-01-01","endDate":"2017-04-30","timeUnit":"month","results":[{"title":"한글","keywords":["한글","korean"],"data":[{"period":"2017-01-01","ratio":47.00101},{"period":"2017-02-01","ratio":53.23619},{"period":"2017-03-01","ratio":100},{"period":"2017-04-01","ratio":85.327}]},{"title":"영어","keywords":["영어","english"],"data":[{"period":"2017-01-01","ratio":40.0881},{"period":"2017-02-01","ratio":36.69942},{"period":"2017-03-01","ratio":52.11792},{"period":"2017-04-01","ratio":44.4595}]}]}

# %%
import urllib.parse
import urllib.request
import json
from openpyxl import load_workbook
import pandas as pd
import requests
from IPython.display import display

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

client_id = "hSEKHkgAg9FvizNuqxMG"
client_secret = "7AlTvkl1LN"

encText = urllib.parse.quote("외대앞 맛집")
num = '&display=20'
sort = '&sort=date'

url = "https://openapi.naver.com/v1/search/blog?query=" + encText + num + sort # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    result = json.loads(response_body)
    df = pd.DataFrame(result['items'])
    display(df)
    df.to_excel('외대 정보.xlsx', sheet_name='맛집 정보')

    # 엑셀 셀 크기 조정하기
    wb = load_workbook('외대 정보.xlsx')
    ws = wb['맛집 정보']

    ws.column_dimensions['B'].width = 100
    ws.column_dimensions['C'].width = 70
    ws.column_dimensions['D'].width = 300
    ws.column_dimensions['E'].width = 50
    ws.column_dimensions['F'].width = 50
    ws.column_dimensions['G'].width = 30
    wb.save('HUFS Info.xlsx')
else:
    print("Error Code:" + rescode)
# Out:
#                                                 title  \
# 0   <b>외대</b><b>맛집</b>:) 믿고 먹는 <b>외대</b>분식 수유리우동집 ...
# 1              청량리 경동시장 스타벅스 경동1960점 방문후기 (ft.경희대...
# 2   [<b>외대앞</b>역] 이터스멕시칸 <b>외대</b>점, 테라스<b>맛집</b>,...
# 3   [<b>외대</b>/동대문]<b>외대</b> <b>맛집</b> 브릴란테에서 스테이크...
# 4                                   [4월 둘째주] 1일 3벚꽃놀이
# 5                                       첫! 만남은 너무 어려워
# 6                     <b>외대</b><b>맛집</b>, 성화금탕마라탕튀김꼬치
# 7                  [회기역] 장군뽈따구_연탄불, 바이브, 그리고 고기.. 갓벽!
# 8                          이문래미안라그란데 분양가 커뮤니티 평면도 배치도
# 9                    회기 <b>외대</b><b>맛집</b> 호헌장담 한식다이닝
# 10                       <b>외대앞</b> 분식<b>맛집</b> ‘떡하니’
# 11           밈블로그 - 수원 인계동 라멘 <b>맛집</b> 신키, 교동 카페...
# 12      캠퍼스, 추천하는 벚꽃데이트 코스 (분위기 <b>맛집</b> &amp; 추천카페)
# 13                            3월 (네?2024 1분기도 끝났다구여?)
# 14                 <b>외대앞</b>역 <b>맛집</b>: 카빙당 먹고 온 후기
# 15                                       어리석은 막학기생이 되
# 16                         향기가 가득한 <b>외대</b>꽃집 라르떼플로라
# 17                   개강과 에버랜드 캐스트 퇴사와 디랩 크루와 막학년을 곁들인
# 18                                    우리는 저물어간 노을 같아요
# 19       <b>외대앞</b>역<b>맛집</b> 성화금탕마라탕튀김꼬치 마라탕 튀김꼬치 추천
#
#                                                  link  \
# 0           https://blog.naver.com/odi01/223411295048
# 1      https://blog.naver.com/iamiramira/223410842419
# 2       https://blog.naver.com/j_seongni/223410052492
# 3        https://blog.naver.com/bobo_log/223409876881
# 4       https://blog.naver.com/mori_1126/223409378563
# 5        https://blog.naver.com/thfdl421/223409256328
# 6   https://blog.naver.com/youngforever_07/2234091...
# 7     https://blog.naver.com/imsujilee91/223408388943
# 8      https://blog.naver.com/sojun_0411/223408359866
# 9     https://blog.naver.com/ddabong1012/223408308100
# 10     https://blog.naver.com/sohadong87/223408186435
# 11        https://blog.naver.com/jjooo_x/223407956717
# 12    https://blog.naver.com/gamjacouple/223407947797
# 13        https://blog.naver.com/95miso_/223407899310
# 14    https://blog.naver.com/chwi_hyang_/223407691325
# 15     https://blog.naver.com/locomental/223407513907
# 16          https://blog.naver.com/odi01/223407451078
# 17   https://blog.naver.com/beatrice2404/223406970518
# 18    https://blog.naver.com/hanbeejjang/223406612816
# 19      https://blog.naver.com/yjoinlove/223406574845
#
#                                           description      bloggername  \
# 0   외대앞떡볶이 #외대앞분식 #<b>외대앞맛집</b> #외대분식맛집 #외대혼밥 #외대역...         냇가 바다되기!
# 1   본관 <b>앞</b> 목련은 이미 다 졌던데 정경대 앞에 목련은 아직 여전하네요 h...      몽쓰의 요리조리 탐험
# 2   오늘 소개해드릴 <b>맛집</b>은 <b>외대앞</b>역 초역세권 2-3분 거리에 ...       우당탕탕 리뷰 맛집
# 3   <b>외대</b> <b>맛집</b>으로 유명한 브릴란테!! <b>외대앞</b> 역 ...             보보로그
# 4   #한국<b>외대</b> #한국외국어대학교 #<b>외대앞</b>역 내 최애 <b>맛집...    모리부부 추억 저장소 ෆ
# 5   우리동네 칼국수 <b>맛집</b> 잉꼬와 약간 실망스러웠던 브런치~ (양이 전보다 ...            THFDL
# 6   혼밥러들 추천합니다. 하여간, 칭따오,,가 아른거린다. 이렇게 <b>외대</b>걸과...      안녕, 나의 기쁨이여
# 7   역시 <b>맛집</b>답게 대기가 있었다. 전화번호를 적어두면 자리날 때 사장님이 ...        그러니까 난데요.
# 8   입지 환경 교통 이문 래미안라그란데는 1호선 신이문역 또는 <b>외대앞</b>역과 ...  현명한 결혼생활을 알려드려요
# 9   직원분들 매우 친절하시고 내부 인터리어도 감각적이고 음식도 너무 힙해요. <b>외대...   행복한 따봉맘의 따봉하우스
# 10  메뉴는: 치즈 라면/깻잎 떡볶이/ 삼겹살 김밥(별 다섯 개 강추) 깻잎떡볶이에 삼겹...      소하동 안사는 소하씨
# 11  08 갈매동에 가면 꼭 먹어줘야 했던 물고기 김밥 갑자기 없어져서 너무너무 슬퍼요 ...  밈블로그 mimi cielo
# 12  경희데데이트장소 #<b>외대</b><b>맛집</b> #경희대<b>맛집</b> #<b...         감자부부의 일상
# 13  휘핑 많이요  신설동_킹수제만두  몰랐던 <b>맛집</b>....만두가 진짜 넘 맛...                ️
# 14  카빙당 #<b>외대앞맛집</b> #<b>외대앞맛집</b> 월-토: 10:00 - 2...      chwi_hyang_
# 15  여성 <b>외대앞</b>에서 레잔도 카이막을 발견하다 가격이랑 양도 비교가 안됩니더...      LOCO_MENTAL
# 16  1,000원할인 <b>외대앞</b> 버스 정류장이자 <b>외대</b>꽃집 라르떼플로...         냇가 바다되기!
# 17  꽤나 쩝쩝박사 소리를 듣는 사람으로 맛집블로그를 한번 키워보고 싶은 생각은 있습니다...        생각을 사유합니다
# 18  저녁엔 학교 앞에서 닭갈비도 먹구 <b>외대</b> 다니면서 닭갈비는 또 처음 먹네...               ㅤㅤ
# 19  or 음료 중 하나를 주는 이벤트가 있었는데 지금은 4월이라 끝났겠네요. 오늘은 <...      용기를 장착한 블로그
#
#                        bloggerlink  postdate
# 0             blog.naver.com/odi01  20240410
# 1        blog.naver.com/iamiramira  20240409
# 2         blog.naver.com/j_seongni  20240409
# 3          blog.naver.com/bobo_log  20240409
# 4         blog.naver.com/mori_1126  20240408
# 5          blog.naver.com/thfdl421  20240408
# 6   blog.naver.com/youngforever_07  20240408
# 7       blog.naver.com/imsujilee91  20240407
# 8        blog.naver.com/sojun_0411  20240407
# 9       blog.naver.com/ddabong1012  20240407
# 10       blog.naver.com/sohadong87  20240407
# 11          blog.naver.com/jjooo_x  20240407
# 12      blog.naver.com/gamjacouple  20240407
# 13          blog.naver.com/95miso_  20240406
# 14      blog.naver.com/chwi_hyang_  20240406
# 15       blog.naver.com/locomental  20240406
# 16            blog.naver.com/odi01  20240406
# 17     blog.naver.com/beatrice2404  20240405
# 18      blog.naver.com/hanbeejjang  20240405
# 19        blog.naver.com/yjoinlove  20240405

# %%
import urllib.parse
import urllib.request
import json
from openpyxl import load_workbook
import pandas as pd
from IPython.display import display

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

client_id = "hSEKHkgAg9FvizNuqxMG"
client_secret = "7AlTvkl1LN"

encText = urllib.parse.quote("외대앞 맛집")
num = '&display=20'
sort = '&sort=date'

url = "https://openapi.naver.com/v1/search/blog?query=" + encText + num + sort # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

try:
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if rescode == 200:
        response_body = response.read()
        result = json.loads(response_body)
        df = pd.DataFrame(result['items'])
        display(df)
        df.to_excel('외대 정보.xlsx', sheet_name='맛집 정보')

        # 엑셀 셀 크기 조정하기
        wb = load_workbook('외대 정보.xlsx')
        ws = wb['맛집 정보']

        ws.column_dimensions['B'].width = 100
        ws.column_dimensions['C'].width = 70
        ws.column_dimensions['D'].width = 300
        ws.column_dimensions['E'].width = 50
        ws.column_dimensions['F'].width = 50
        ws.column_dimensions['G'].width = 30
        wb.save('HUFS Info.xlsx')
    else:
        print("Error Code:", rescode)
except urllib.error.HTTPError as e:
    print("HTTP 에러가 발생했습니다:", e.code)
# Out:
#                                                 title  \
# 0   <b>외대</b><b>맛집</b>:) 믿고 먹는 <b>외대</b>분식 수유리우동집 ...
# 1              청량리 경동시장 스타벅스 경동1960점 방문후기 (ft.경희대...
# 2   [<b>외대앞</b>역] 이터스멕시칸 <b>외대</b>점, 테라스<b>맛집</b>,...
# 3   [<b>외대</b>/동대문]<b>외대</b> <b>맛집</b> 브릴란테에서 스테이크...
# 4                                   [4월 둘째주] 1일 3벚꽃놀이
# 5                                       첫! 만남은 너무 어려워
# 6                     <b>외대</b><b>맛집</b>, 성화금탕마라탕튀김꼬치
# 7                  [회기역] 장군뽈따구_연탄불, 바이브, 그리고 고기.. 갓벽!
# 8                          이문래미안라그란데 분양가 커뮤니티 평면도 배치도
# 9                    회기 <b>외대</b><b>맛집</b> 호헌장담 한식다이닝
# 10                       <b>외대앞</b> 분식<b>맛집</b> ‘떡하니’
# 11           밈블로그 - 수원 인계동 라멘 <b>맛집</b> 신키, 교동 카페...
# 12      캠퍼스, 추천하는 벚꽃데이트 코스 (분위기 <b>맛집</b> &amp; 추천카페)
# 13                            3월 (네?2024 1분기도 끝났다구여?)
# 14                 <b>외대앞</b>역 <b>맛집</b>: 카빙당 먹고 온 후기
# 15                                       어리석은 막학기생이 되
# 16                         향기가 가득한 <b>외대</b>꽃집 라르떼플로라
# 17                   개강과 에버랜드 캐스트 퇴사와 디랩 크루와 막학년을 곁들인
# 18                                    우리는 저물어간 노을 같아요
# 19       <b>외대앞</b>역<b>맛집</b> 성화금탕마라탕튀김꼬치 마라탕 튀김꼬치 추천
#
#                                                  link  \
# 0           https://blog.naver.com/odi01/223411295048
# 1      https://blog.naver.com/iamiramira/223410842419
# 2       https://blog.naver.com/j_seongni/223410052492
# 3        https://blog.naver.com/bobo_log/223409876881
# 4       https://blog.naver.com/mori_1126/223409378563
# 5        https://blog.naver.com/thfdl421/223409256328
# 6   https://blog.naver.com/youngforever_07/2234091...
# 7     https://blog.naver.com/imsujilee91/223408388943
# 8      https://blog.naver.com/sojun_0411/223408359866
# 9     https://blog.naver.com/ddabong1012/223408308100
# 10     https://blog.naver.com/sohadong87/223408186435
# 11        https://blog.naver.com/jjooo_x/223407956717
# 12    https://blog.naver.com/gamjacouple/223407947797
# 13        https://blog.naver.com/95miso_/223407899310
# 14    https://blog.naver.com/chwi_hyang_/223407691325
# 15     https://blog.naver.com/locomental/223407513907
# 16          https://blog.naver.com/odi01/223407451078
# 17   https://blog.naver.com/beatrice2404/223406970518
# 18    https://blog.naver.com/hanbeejjang/223406612816
# 19      https://blog.naver.com/yjoinlove/223406574845
#
#                                           description      bloggername  \
# 0   외대앞떡볶이 #외대앞분식 #<b>외대앞맛집</b> #외대분식맛집 #외대혼밥 #외대역...         냇가 바다되기!
# 1   본관 <b>앞</b> 목련은 이미 다 졌던데 정경대 앞에 목련은 아직 여전하네요 h...      몽쓰의 요리조리 탐험
# 2   오늘 소개해드릴 <b>맛집</b>은 <b>외대앞</b>역 초역세권 2-3분 거리에 ...       우당탕탕 리뷰 맛집
# 3   <b>외대</b> <b>맛집</b>으로 유명한 브릴란테!! <b>외대앞</b> 역 ...             보보로그
# 4   #한국<b>외대</b> #한국외국어대학교 #<b>외대앞</b>역 내 최애 <b>맛집...    모리부부 추억 저장소 ෆ
# 5   우리동네 칼국수 <b>맛집</b> 잉꼬와 약간 실망스러웠던 브런치~ (양이 전보다 ...            THFDL
# 6   혼밥러들 추천합니다. 하여간, 칭따오,,가 아른거린다. 이렇게 <b>외대</b>걸과...      안녕, 나의 기쁨이여
# 7   역시 <b>맛집</b>답게 대기가 있었다. 전화번호를 적어두면 자리날 때 사장님이 ...        그러니까 난데요.
# 8   입지 환경 교통 이문 래미안라그란데는 1호선 신이문역 또는 <b>외대앞</b>역과 ...  현명한 결혼생활을 알려드려요
# 9   직원분들 매우 친절하시고 내부 인터리어도 감각적이고 음식도 너무 힙해요. <b>외대...   행복한 따봉맘의 따봉하우스
# 10  메뉴는: 치즈 라면/깻잎 떡볶이/ 삼겹살 김밥(별 다섯 개 강추) 깻잎떡볶이에 삼겹...      소하동 안사는 소하씨
# 11  08 갈매동에 가면 꼭 먹어줘야 했던 물고기 김밥 갑자기 없어져서 너무너무 슬퍼요 ...  밈블로그 mimi cielo
# 12  경희데데이트장소 #<b>외대</b><b>맛집</b> #경희대<b>맛집</b> #<b...         감자부부의 일상
# 13  휘핑 많이요  신설동_킹수제만두  몰랐던 <b>맛집</b>....만두가 진짜 넘 맛...                ️
# 14  카빙당 #<b>외대앞맛집</b> #<b>외대앞맛집</b> 월-토: 10:00 - 2...      chwi_hyang_
# 15  여성 <b>외대앞</b>에서 레잔도 카이막을 발견하다 가격이랑 양도 비교가 안됩니더...      LOCO_MENTAL
# 16  1,000원할인 <b>외대앞</b> 버스 정류장이자 <b>외대</b>꽃집 라르떼플로...         냇가 바다되기!
# 17  꽤나 쩝쩝박사 소리를 듣는 사람으로 맛집블로그를 한번 키워보고 싶은 생각은 있습니다...        생각을 사유합니다
# 18  저녁엔 학교 앞에서 닭갈비도 먹구 <b>외대</b> 다니면서 닭갈비는 또 처음 먹네...               ㅤㅤ
# 19  or 음료 중 하나를 주는 이벤트가 있었는데 지금은 4월이라 끝났겠네요. 오늘은 <...      용기를 장착한 블로그
#
#                        bloggerlink  postdate
# 0             blog.naver.com/odi01  20240410
# 1        blog.naver.com/iamiramira  20240409
# 2         blog.naver.com/j_seongni  20240409
# 3          blog.naver.com/bobo_log  20240409
# 4         blog.naver.com/mori_1126  20240408
# 5          blog.naver.com/thfdl421  20240408
# 6   blog.naver.com/youngforever_07  20240408
# 7       blog.naver.com/imsujilee91  20240407
# 8        blog.naver.com/sojun_0411  20240407
# 9       blog.naver.com/ddabong1012  20240407
# 10       blog.naver.com/sohadong87  20240407
# 11          blog.naver.com/jjooo_x  20240407
# 12      blog.naver.com/gamjacouple  20240407
# 13          blog.naver.com/95miso_  20240406
# 14      blog.naver.com/chwi_hyang_  20240406
# 15       blog.naver.com/locomental  20240406
# 16            blog.naver.com/odi01  20240406
# 17     blog.naver.com/beatrice2404  20240405
# 18      blog.naver.com/hanbeejjang  20240405
# 19        blog.naver.com/yjoinlove  20240405

# %% [markdown]
# #### 다음시간: 전처리
