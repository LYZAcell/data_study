# %% [markdown]
# <a href="https://colab.research.google.com/github/LYZAcell/data_study/blob/main/'BDA(%ED%86%B5%EA%B3%84)/%EC%9D%B4%EA%B0%80%EC%98%81_41_%EC%B5%9C%EC%A2%85%EA%B3%BC%EC%A0%9C_%EC%A0%9C%EC%B6%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 분석
#
# ## 목적1: 홍보 경로 분석 (전공, 유입 시기)
# - 부차적으로 다양한 희망 직무와 학회내에서 이루어졌던 설명회 매칭
# - 상점 df활용
#
#
# ## 목적2: 재참여율 분석
# - 각분기에 참여했떤 반과 8기에 참여를 원하는 반
# - 재참여 시 신청률이 가장 높은 반
# - 전체에서 가장 인기가 많은 반 1,2 가리기 (초/중급도 분류하기)

# %% [markdown]
# ## 1. df 및 라이브러리 호출
# - 각종 df 호출 및 컬럼명 확인

# %%
# xlsx 안열릴경우 실행
# !pip install openpyxl==3.1.2
# Out:
# Collecting openpyxl==3.1.2
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl==3.1.2) (1.1.0)
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: openpyxl
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 3.1.5
#     Uninstalling openpyxl-3.1.5:
#       Successfully uninstalled openpyxl-3.1.5
# Successfully installed openpyxl-3.1.2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
point_df = pd.read_excel('8기 학회원 트레인데이터 - 상점.xlsx')
repar_df = pd.read_excel('8기 학회원 트레인데이터 - 재참여가능성.xlsx')
satis_df = pd.read_excel('8기 학회원 트레인데이터 - 학회만족도.xlsx')

# %%
point_df.head(3)
# Out:
#    상벌점 총점  \
# 0    -8.0
# 1     NaN
# 2   -77.0
#
#   6-7) 본인이 현재 학업 외 데이터 분석 공부에 투입 가능한 하루 최대 시간은 몇 시간인가요? (2시간인 경우, 2로 적어주세요)  \
# 0                                                4~5
# 1                                                  1
# 2                                                  2
#
#   2-13) 현재 본인의 직업을 알려주세요. 2-7) 본인의 (최종) 전공 대학 구분을 선택해주세요. ( 복수선택 가능 )  \
# 0         대학교 이수학기 4학기 이하                              공학 (컴퓨터 공학 제외)
# 1         대학교 이수학기 4학기 이하                                         의약학
# 2         대학교 이수학기 5학기 이상                              IT (컴퓨터 공학 포함)
#
#   3-1) 직업 내용을 작성해주세요. 7-1) 데이터 분석 제외 교육 받고 싶은 직무를 선택해 주세요.  \
# 0                 NaN                                   개발
# 1                 NaN                                   개발
# 2                 NaN                                   AI
#
#   6-9) 희망 직무를 선택해주세요. (마케터, 개발자, 데이터 분석가 등) 6-10) 희망 직무에 데이터 역량이 필요한가요?  \
# 0                                  데이터 엔지니어                         그렇다
# 1                                  인공지능 전문가                         그렇다
# 2                                  인공지능 전문가                         그렇다
#
#   2-12) 졸업 후 진로를 선택해주세요. 6-11) BDA 학회에서 가장 얻고자 하는 1가지는 무엇인가요?  ...  \
# 0                     취업                              프로젝트 경험  ...
# 1                 대학원 진학                            데이터 분석 역량  ...
# 2                     취업                              프로젝트 경험  ...
#
#   6-6) BDA 인스타그램을 팔로우 하셨나요?  \
# 0                       아니요
# 1                         예
# 2                         예
#
#   2-11) 재학생의 경우 2024-1학기에 듣는 학점을 적어주세요. ( 예시 : 18학점 -> 18 )  \
# 0                                                NaN
# 1                                                 24
# 2                                                 18
#
#   6-5) BDA에서 진행되는 조별활동에 참여하실 의향이 있으신가요?  \
# 0                    네. 오프라인으로 참여하고 싶어요
# 1                     네. 온라인으로 참여하고 싶어요
# 2                    네. 오프라인으로 참여하고 싶어요
#
#   6-7) 본인이 현재 학업 외 데이터 분석 공부에 투입 가능한 하루 최대 시간은 몇 시간인가요? (2시간인 경우, 2로 적어주세요).1  \
# 0                                                4~5
# 1                                                  1
# 2                                                  2
#
#   7-11) 데이터 관련 스터디, 동아리, 학회 참여 경험이 있으신가요? 8-1) 참여 경험이 있는 항목에 모두 선택해주세요.  \
# 0                                      없음                           NaN
# 1                                      없음                           NaN
# 2                                      없음                           NaN
#
#   9-1) 데이터 활용 공모전, 프로젝트 참여 경험이 있으신가요?   11-1) 데이터 관련 직무 경험(인턴 등)이 있으신가요?    \
# 0                                  없음                                   없음
# 1                                  없음                                   없음
# 2                                  없음                                   없음
#
#   13-1) 구독중인 뉴스레터가 있나요?   14-2) 어떤 분야의 뉴스레터를 구독하고 있나요? (중복 가능)
# 0                     아니요                                    NaN
# 1                     아니요                                    NaN
# 2                     아니요                                    NaN
#
# [3 rows x 21 columns]

# %%
point_df.columns
# Out:
# Index(['상벌점 총점',
#        '6-7) 본인이 현재 학업 외 데이터 분석 공부에 투입 가능한 하루 최대 시간은 몇 시간인가요? (2시간인 경우, 2로 적어주세요)',
#        '2-13) 현재 본인의 직업을 알려주세요.',
#        '2-7) 본인의 (최종) 전공 대학 구분을 선택해주세요. ( 복수선택 가능 )', '3-1) 직업 내용을 작성해주세요.',
#        '7-1) 데이터 분석 제외 교육 받고 싶은 직무를 선택해 주세요.',
#        '6-9) 희망 직무를 선택해주세요. (마케터, 개발자, 데이터 분석가 등)',
#        '6-10) 희망 직무에 데이터 역량이 필요한가요?', '2-12) 졸업 후 진로를 선택해주세요.',
#        '6-11) BDA 학회에서 가장 얻고자 하는 1가지는 무엇인가요?', '유입 경로를 알려주세요.',
#        '6-6) BDA 인스타그램을 팔로우 하셨나요?',
#        '2-11) 재학생의 경우 2024-1학기에 듣는 학점을 적어주세요. ( 예시 : 18학점 -> 18 )',
#        '6-5) BDA에서 진행되는 조별활동에 참여하실 의향이 있으신가요?',
#        '6-7) 본인이 현재 학업 외 데이터 분석 공부에 투입 가능한 하루 최대 시간은 몇 시간인가요? (2시간인 경우, 2로 적어주세요).1',
#        '7-11) 데이터 관련 스터디, 동아리, 학회 참여 경험이 있으신가요?',
#        '8-1) 참여 경험이 있는 항목에 모두 선택해주세요.', '9-1) 데이터 활용 공모전, 프로젝트 참여 경험이 있으신가요?',
#        '  11-1) 데이터 관련 직무 경험(인턴 등)이 있으신가요?  ', '13-1) 구독중인 뉴스레터가 있나요?  ',
#        '14-2) 어떤 분야의 뉴스레터를 구독하고 있나요? (중복 가능)  '],
#       dtype='object')

# %%
repar_df.head(3)
# Out:
#    7기 참여 여부 2-7) 본인의 (최종) 전공 대학 구분을 선택해주세요. ( 복수선택 가능 )  \
# 0         0                              공학 (컴퓨터 공학 제외)
# 1         0                                         의약학
# 2         0                              IT (컴퓨터 공학 포함)
#
#   2-9) 본인의 (최종) 학과명을 적어주세요. (  예시 :  OO학과 )  \
# 0                                    신소재공학과
# 1                                       의예과
# 2                                    IT공학고ㅓ
#
#   2-10) 본인의 복수전공명을 적어주세요. (  예시 :  OO학과 ) 2-12) 졸업 후 진로를 선택해주세요.  \
# 0                                     NaN                     취업
# 1                                     NaN                 대학원 진학
# 2                                  빅데이터학과                     취업
#
#   6-9) 희망 직무를 선택해주세요. (마케터, 개발자, 데이터 분석가 등) 6-10) 희망 직무에 데이터 역량이 필요한가요?  \
# 0                                  데이터 엔지니어                         그렇다
# 1                                  인공지능 전문가                         그렇다
# 2                                  인공지능 전문가                         그렇다
#
#   6-7) 본인이 현재 학업 외 데이터 분석 공부에 투입 가능한 하루 최대 시간은 몇 시간인가요? (2시간인 경우, 2로 적어주세요)  \
# 0                                                4~5
# 1                                                  1
# 2                                                  2
#
#    BDA를 친구/지인 등 주변에 얼마나 추천하고 싶으신가요? 7-11) 데이터 관련 스터디, 동아리, 학회 참여 경험이 있으신가요?  \
# 0                               NaN                                      없음
# 1                               NaN                                      없음
# 2                               NaN                                      없음
#
#   8-1) 참여 경험이 있는 항목에 모두 선택해주세요. 9-1) 데이터 활용 공모전, 프로젝트 참여 경험이 있으신가요?  \
# 0                           NaN                                  없음
# 1                           NaN                                  없음
# 2                           NaN                                  없음
#
#     11-1) 데이터 관련 직무 경험(인턴 등)이 있으신가요?   13-1) 구독중인 뉴스레터가 있나요?    \
# 0                                   없음                     아니요
# 1                                   없음                     아니요
# 2                                   없음                     아니요
#
#   14-2) 어떤 분야의 뉴스레터를 구독하고 있나요? (중복 가능)
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN

# %%
repar_df.columns
# Out:
# Index(['7기 참여 여부', '2-7) 본인의 (최종) 전공 대학 구분을 선택해주세요. ( 복수선택 가능 )',
#        '2-9) 본인의 (최종) 학과명을 적어주세요. (  예시 :  OO학과 )',
#        '2-10) 본인의 복수전공명을 적어주세요. (  예시 :  OO학과 )', '2-12) 졸업 후 진로를 선택해주세요.',
#        '6-9) 희망 직무를 선택해주세요. (마케터, 개발자, 데이터 분석가 등)',
#        '6-10) 희망 직무에 데이터 역량이 필요한가요?',
#        '6-7) 본인이 현재 학업 외 데이터 분석 공부에 투입 가능한 하루 최대 시간은 몇 시간인가요? (2시간인 경우, 2로 적어주세요)',
#        'BDA를 친구/지인 등 주변에 얼마나 추천하고 싶으신가요?',
#        '7-11) 데이터 관련 스터디, 동아리, 학회 참여 경험이 있으신가요?',
#        '8-1) 참여 경험이 있는 항목에 모두 선택해주세요.', '9-1) 데이터 활용 공모전, 프로젝트 참여 경험이 있으신가요?',
#        '  11-1) 데이터 관련 직무 경험(인턴 등)이 있으신가요?  ', '13-1) 구독중인 뉴스레터가 있나요?  ',
#        '14-2) 어떤 분야의 뉴스레터를 구독하고 있나요? (중복 가능)  '],
#       dtype='object')

# %%
satis_df.head(3)
# Out:
#   1-1) BDA 학회에 참여하신 적이 있으십니까? 1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [3기]  \
# 0                         아니요                                             NaN
# 1                         아니요                                             NaN
# 2                         아니요                                             NaN
#
#   1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [4기]  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
#   1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [5기]  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
#   1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [6기]  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
#   1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [7기]  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
#    1-4) 8기에 참여를 원하는 분반 번호를 선택해주세요.  1-4) 8기에 참여를 원하는 첫 번째 분반 번호를 선택해주세요.  \
# 0                              4.0                                   NaN
# 1                              NaN                                   9.0
# 2                              4.0                                   NaN
#
#    1-5) 8기에 참여를 원하는 두 번째 분반 번호를 선택해주세요.  \
# 0                                   NaN
# 1                                   1.0
# 2                                   NaN
#
#   2-7) 본인의 (최종) 전공 대학 구분을 선택해주세요. ( 복수선택 가능 )  ... 2-12) 졸업 후 진로를 선택해주세요.  \
# 0                              공학 (컴퓨터 공학 제외)  ...                     취업
# 1                                         의약학  ...                 대학원 진학
# 2                              IT (컴퓨터 공학 포함)  ...                     취업
#
#   2-13) 현재 본인의 직업을 알려주세요. 3-1) 직업 내용을 작성해주세요. 유입 경로를 알려주세요.  \
# 0         대학교 이수학기 4학기 이하                 NaN         에브리타임
# 1         대학교 이수학기 4학기 이하                 NaN         에브리타임
# 2         대학교 이수학기 5학기 이상                 NaN         에브리타임
#
#   5-2) 추천인의 참여 기수와 분반을 적어주세요  6-9) 희망 직무를 선택해주세요. (마케터, 개발자, 데이터 분석가 등)  \
# 0                         NaN                                  데이터 엔지니어
# 1                         NaN                                  인공지능 전문가
# 2                         NaN                                  인공지능 전문가
#
#   6-10) 희망 직무에 데이터 역량이 필요한가요? 6-11) BDA 학회에서 가장 얻고자 하는 1가지는 무엇인가요?  \
# 0                         그렇다                              프로젝트 경험
# 1                         그렇다                            데이터 분석 역량
# 2                         그렇다                              프로젝트 경험
#
#   6-7) 본인이 현재 학업 외 데이터 분석 공부에 투입 가능한 하루 최대 시간은 몇 시간인가요? (2시간인 경우, 2로 적어주세요)  \
# 0                                                4~5
# 1                                                  1
# 2                                                  2
#
#   BDA를 친구/지인 등 주변에 얼마나 추천하고 싶으신가요?
# 0                              NaN
# 1                              NaN
# 2                              NaN
#
# [3 rows x 22 columns]

# %%
satis_df.columns
# Out:
# Index(['1-1) BDA 학회에 참여하신 적이 있으십니까?',
#        '1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [3기]',
#        '1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [4기]',
#        '1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [5기]',
#        '1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [6기]',
#        '1-2) 이전에 참여했던 기수와 분반을 모두 선택해주세요. (복수선택 가능) [7기]',
#        '1-4) 8기에 참여를 원하는 분반 번호를 선택해주세요.',
#        '1-4) 8기에 참여를 원하는 첫 번째 분반 번호를 선택해주세요.',
#        '1-5) 8기에 참여를 원하는 두 번째 분반 번호를 선택해주세요.',
#        '2-7) 본인의 (최종) 전공 대학 구분을 선택해주세요. ( 복수선택 가능 )',
#        '2-9) 본인의 (최종) 학과명을 적어주세요. (  예시 :  OO학과 )',
#        '2-10) 본인의 복수전공명을 적어주세요. (  예시 :  OO학과 )', '2-12) 졸업 후 진로를 선택해주세요.',
#        '2-13) 현재 본인의 직업을 알려주세요.', '3-1) 직업 내용을 작성해주세요.', '유입 경로를 알려주세요.',
#        '5-2) 추천인의 참여 기수와 분반을 적어주세요 ',
#        '6-9) 희망 직무를 선택해주세요. (마케터, 개발자, 데이터 분석가 등)',
#        '6-10) 희망 직무에 데이터 역량이 필요한가요?', '6-11) BDA 학회에서 가장 얻고자 하는 1가지는 무엇인가요?',
#        '6-7) 본인이 현재 학업 외 데이터 분석 공부에 투입 가능한 하루 최대 시간은 몇 시간인가요? (2시간인 경우, 2로 적어주세요)',
#        'BDA를 친구/지인 등 주변에 얼마나 추천하고 싶으신가요?'],
#       dtype='object')
